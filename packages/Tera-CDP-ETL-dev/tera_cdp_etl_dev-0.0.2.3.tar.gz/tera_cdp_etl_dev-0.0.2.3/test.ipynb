# %%
schema = {
    "fields": [
        {
            "name": "UserId",
            "fieldType": "string",
            "comment": "",
            "validation_rule": ""
        },
        # {
        #     "name": "UserIdHD",
        #     "fieldType": "string",
        #     "comment": "",
        #     "validation_rule": ""
        # },
        {
            "name": "HomePhone",
            "fieldType": "string",
            "comment": "",
            "validation_rule": ""
        },
        {
            "name": "WorkPhone",
            "fieldType": [
                "string",
                "null"
            ],
            "comment": "",
            "validation_rule": ""
        },
        {
            "name": "Address",
            "fieldType": "object",
            "comment": "",
            "validation_rule": "",
            "properties": [
                {
                    "name": "HouseNo",
                    "fieldType": "string",
                    "comment": "",
                    "validation_rule": ""
                },
                {
                    "name": "Streetname",
                    "fieldType": "string",
                    "comment": "",
                    "validation_rule": ""
                },
                {
                    "name": "Ward",
                    "fieldType": "string",
                    "comment": "",
                    "validation_rule": ""
                },
                {
                    "name": "District",
                    "fieldType": "string",
                    "comment": "",
                    "validation_rule": ""
                },
                {
                    "name": "Province",
                    "fieldType": "string",
                    "comment": "",
                    "validation_rule": ""
                },
                {
                    "name": "Country",
                    "fieldType": "string",
                    "comment": "",
                    "validation_rule": ""
                }
            ]
        },
        {
            "name": "Firstname",
            "fieldType": "string",
            "comment": "",
            "validation_rule": ""
        },
        {
            "name": "Lastname",
            "fieldType": "string",
            "comment": "",
            "validation_rule": ""
        },
        {
            "name": "Gender",
            "fieldType": "string",
            "comment": "",
            "validation_rule": ""
        },
        {
            "name": "RegisterDate",
            "fieldType": "datetime",
            "comment": "",
            "validation_rule": ""
        },
        {
            "name": "Status",
            "fieldType": "string",
            "comment": "",
            "validation_rule": ""
        },
        {
            "name": "DataSource",
            "fieldType": "string",
            "comment": "",
            "validation_rule": ""
        },
        {
            "name": "Source",
            "fieldType": "string",
            "comment": "",
            "validation_rule": ""
        },
        {
            "name": "EventId",
            "fieldType": "string",
            "comment": "",
            "validation_rule": ""
        }
    ]
}

data = {
    "UserId": 202201439424,
    "HomePhone": "0912919543",
    "WorkPhone": None,
    "Address": {
        "HouseNo": "",
        "Streetname": "",
        "Ward": "ẤP HÒA CƯỜNG, Xã Minh Hoà",
        "District": "Huyện Dầu Tiếng",
        "Province": "Tỉnh Bình Dương",
        "Country": "Việt Nam"
    },
    "Firstname": "TRẦN VĂN ",
    "Lastname": "TÙNG",
    "Gender": "Male",
    "RegisterDate": "2022-01-01T00:00:00.00Z",
    "Status": "True",
    "DataSource": "VTVHyundai",
    "Source": "VTVHyundai",
    "EventId": "VTVHyundai_IngestProfile_202201439424",
}

# %%
import airflow.dags.schema_validator as schema_validator
def build_path(path, key):
    return key if len(path) == 0 else path + '.' + key
def get_default_value(m_key):
    # Model field is an array of objects
    # case1:     foo: [{bar: ['string', 'value']}]
    if type(m_key) is list and type(m_key[0]) is dict:
        return []

    # Model field is an object
    # case2:     foo: {bar: ['string', 'value']}
    if type(m_key) is dict:
        res = {}
        for key in m_key.keys():
            res[key] = get_default_value(m_key[key])
        return res

    # case3:     foo: ['string', 'value']
    return m_key[1]

# %%
schema = {
    "Fields": [
      {"Name": "UserId", "FieldType": "string", "Validation": "String,MustHave", "Comment": "id của user trong hệ thống, phải là kiểu string" },
      {"Name": "HomePhone", "FieldType": "string", "Comment": "Nếu không có thì để trống" },
      {"Name": "WorkPhone", "FieldType": ["string", "null"], "Comment": "Nếu không có thì để trống" },
      {"Name": "AddrHouseNo", "FieldType": "string", "Comment": "Số nhà" },
      {"Name": "AddrStreetName", "FieldType": "string", "Comment": "Tên đường" },
      {"Name": "AddrWard", "FieldType": "string", "Comment": "Phường / Xã" },
      {"Name": "AddrDistrict", "FieldType": "string", "Comment": "Quận / Huyện / Thành Phố trực thuộc tỉnh" },
      {"Name": "AddrProvince", "FieldType": "string", "Comment": "Tỉnh / Thành phố trực thuộc TW" },
      {"Name": "AddrCountry", "FieldType": "string", "Validation": "Iso Country Code", "Comment": "Tên nước - ISO Country Code - E.g. VN" },
      {"Name": "Firstname", "FieldType": "string", "Comment": "Tên" },
      {"Name": "Lastname", "FieldType": "string", "Comment": "Họ và chữ lót" },
      {"Name": "Gender", "FieldType": "string", "Comment": "Giới tính, tiếng anh, để khỏi bị nhầm lẫn", "Validation": "Male/Female/Other" },
      {"Name": "RegisterDate", "FieldType": "string", "Comment": "Ngày đăng ký vào hệ thống" },
      {"Name": "DataSource", "FieldType": "string", "Comment": "DataProviderName" },
      {"Name": "MaritalStatus", "FieldType": "string", "Comment": "Tình trạng hôn nhân", "Validation": "Single/Married" }
    ]
  }

# %%
# errors = schema_validator.validate_v2(schema,data)\
schema_dict = {}
for field in schema["fields"]:
    if field["fieldType"] == "object":
        schema_dict[field["name"]] = {}
        for property in field["properties"]:
            schema_dict[field["name"]][property["name"]] = property["fieldType"]
    else:
        schema_dict[field["name"]] = field["fieldType"]
path = ""
result = []
print(schema_dict)

# %%
for field in data:
    if field not in list_field_name:
        fullpath = build_path(path, field)
        field_type = type(data[field]).__name__
        error_response = {
            'msg': '[+] Extra field: "{}" having type: "{}"'.format(fullpath, field_type),
            'type': 'extra_field',
            'path': fullpath,
            'field_type': field_type
        }
        result.append(error_response)

# %%
print(list_field_name)
print(result)

# %%
type_field = schema["fields"][]
for key in list_field_name:
    if key not in data:
        fullpath = build_path(path, key)
        error_response = {
            'msg': '[-] Missing field: "{}"'.format(fullpath),
            'type': 'missing_field',
            'path': fullpath,
            'default_value': get_default_value([key])
        }
        result.append(error_response)
        continue

# %%
schema = {
    "UserId" : "int",
    "HomePhone" : "string",
    "WorkPhone" : ["string", "null"],
    "Address" : {
        "HouseNo": "string",
        "Streetname": "string",
        "Ward": "string",
        "District": "string",
        "Province": "string",
        "Country": "string"
    },
    "Firstname" : "string",
    "Lastname" : "string",
    "Gender" : "string",
    "RegisterDate" : "datetime",
    "Status" : "string",
    "DataSource" : "string",
    "Source" : "string",
    "EventId" : "string"
}
data = {
    "UserId": 202201439424,
    "HomePhone": "0912919543",
    "WorkPhone": None,
    "Address": {
        "HouseNo": "",
        "Streetname": "",
        "Ward": "ẤP HÒA CƯỜNG, Xã Minh Hoà",
        "District": "Huyện Dầu Tiếng",
        "Province": "Tỉnh Bình Dương",
        "Country": "Việt Nam"
    },
    "Firstname": "TRẦN VĂN ",
    "Lastname": "TÙNG",
    "Gender": "Male",
    "RegisterDate": "2022-01-01T00:00:00.00Z",
    "Status": "True",
    "DataSource": "VTVHyundai",
    "Source": "VTVHyundai",
    "EventId": "VTVHyundai_IngestProfile_202201439424"
}
a = schema_validator.validate(schema,data)

# %%
a

# %%
from enum import Enum
import os
class S3BucketConfig(Enum):
    QC_BUCKET = 'teracdp-data-quality'
    QC_ACCEPT_PATH = 'accept'
    QC_REJECT_PATH = 'reject'
print(S3BucketConfig.QC_BUCKET.value)
print(os.path.join(*[S3BucketConfig.QC_ACCEPT_PATH.value, "data_source", "uploaded_date", "event_name", "filename"]))

# %%
import boto3
from boto3.dynamodb.conditions import Attr, And, Key
from functools import reduce
DYNAMODB_DATA_SCHEMA_TABLE = 'SchemaRegistry'
DYNAMODB_DATA_PROVIDER_SCHEMA = 'DataProviderSchema'
DYNAMODB_DATA_QUALITY_CONTROL_LOG = 'QualityControlLog'
dynamodb_resource = boto3.resource(
        'dynamodb',
        aws_access_key_id="AKIAZQSLELDPHSPH6LFK",
        aws_secret_access_key="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",
        region_name="ap-southeast-1",
    )
table = dynamodb_resource.Table(DYNAMODB_DATA_PROVIDER_SCHEMA) 
attribs = {'DataProvider':"VTVHuyndai", 'EventName':"IngestProfile"}
response = table.scan(
    FilterExpression=(
        reduce(And, [Key(k).eq(v) for k, v in attribs.items()])
    )
)
rows = response.get('Items')

# %%
print(rows)

# %%
from tera_etl import quality_control as qc
schema = {
    "UserId" : "int",
    "HomePhone" : "string",
    "WorkPhone" : ["string", "null"],
    "Address" : {
        "HouseNo": "string",
        "Streetname": "string",
        "Ward": "string",
        "District": "string",
        "Province": "string",
        "Country": "string"
    },
    "Firstname" : "string",
    "Lastname" : "string",
    "Gender" : "string",
    "RegisterDate" : "datetime",
    "Status" : "string",
    "DataSource" : "string",
    "Source" : "string",
    "EventId" : "string"
}
data = {
    "UserId": 202201439424,
    "HomePhone": "0912919543",
    "WorkPhone": None,""
    "Address": {
        "HouseNo": "",
        "Streetname": "",
        "Ward": "ẤP HÒA CƯỜNG, Xã Minh Hoà",
        "District": "Huyện Dầu Tiếng",
        "Province": "Tỉnh Bình Dương",
        "Country": "Việt Nam"
    },
    "Firstname": "TRẦN VĂN ",
    "Lastname": "TÙNG",
    "Gender": "Male",
    "RegisterDate": "2022-01-01T00:00:00.00Z",
    "DataSource": "VTVHyundai",
    "MaritalStatus": "Single",
}

structures = {
    "Fields": [
      {"Name": "UserId", "FieldType": "string", "Validation": "String,MustHave", "Comment": "id của user trong hệ thống, phải là kiểu string" },
      {"Name": "HomePhone", "FieldType": ["string", "null"], "Comment": "Nếu không có thì để trống" },
      {"Name": "WorkPhone", "FieldType": ["string", "null"], "Comment": "Nếu không có thì để trống" },
      {"Name": "AddrHouseNo", "FieldType": "string", "Comment": "Số nhà" },
      {"Name": "AddrStreetName", "FieldType": "string", "Comment": "Tên đường" },
      {"Name": "AddrWard", "FieldType": "string", "Comment": "Phường / Xã" },
      {"Name": "AddrDistrict", "FieldType": "string", "Comment": "Quận / Huyện / Thành Phố trực thuộc tỉnh" },
      {"Name": "AddrProvince", "FieldType": "string", "Comment": "Tỉnh / Thành phố trực thuộc TW" },
      {"Name": "AddrCountry", "FieldType": "string", "Validation": "Iso Country Code", "Comment": "Tên nước - ISO Country Code - E.g. VN" },
      {"Name": "Firstname", "FieldType": "string", "Comment": "Tên" },
      {"Name": "Lastname", "FieldType": "string", "Comment": "Họ và chữ lót" },
      {"Name": "Gender", "FieldType": "string", "Comment": "Giới tính, tiếng anh, để khỏi bị nhầm lẫn", "Validation": "Male/Female/Other" },
      {"Name": "RegisterDate", "FieldType": "datetime", "Comment": "Ngày đăng ký vào hệ thống" },
      {"Name": "DataSource", "FieldType": "string", "Comment": "DataProviderName" },
      {"Name": "MaritalStatus", "FieldType": "string", "Comment": "Tình trạng hôn nhân", "Validation": "Single/Married" }
    ]
  }
data = {
    "UserId": 202201439260,
    "HomePhone": "0369841490",
    "WorkPhone": None,
    "AddrHouseNo": "",
    "AddrStreetname": "",
    "AddrWard": "15 NGÕ 341, Phường Xuân Phương",
    "AddrDistrict": "Quận Nam Từ Liêm",
    "AddrProvince": "Thành phố Hà Nội",
    "AddrCountry": "Việt Nam",
    "Firstname": "NGUYỄN THỊ BÍCH ",
    "Lastname": "HIỀN",
    "Gender": "Female",
    "RegisterDate": "2022-01-01T00:00:00.00Z",
    "DataSource": "VTVHyundai",
    "MaritalStatus": "Single"
}
schema = {
    'UserId': 'string',
    'HomePhone': ['string', 'null'],
    'WorkPhone': ['string', 'null'],
    'AddrHouseNo': 'string',
    'AddrStreetName': 'string',
    'AddrWard': 'string',
    'AddrDistrict': 'string',
    'AddrProvince': 'string',
    'AddrCountry': 'string',
    'Firstname': 'string',
    'Lastname': 'string',
    'Gender': 'string',
    'RegisterDate': 'datetime',
    'DataSource': 'string',
    'MaritalStatus': 'string'
}

# schema_dict={}
# for field in structures["Fields"]:
#     schema_dict[field["Name"]] = field["FieldType"]
# print(schema_dict)
qc_type = qc.classify_data(data_chunk=data, schema=schema)
print(qc_type)

# %%
schema_dict = {}
for field in structures["Fields"]:
    # if field["fieldType"] == "object":
    #     schema_dict[field["name"]] = {}
    #     for property in field["properties"]:
    #         schema_dict[field["name"]][property["name"]] = property["fieldType"]
    # else:
    schema_dict[field["Name"]] = field["FieldType"]
print(schema_dict)

# %%
from enum import Enum
class QualityControlStatus(Enum):
    SUCCESS = 'SUCCESS'
    FAILURE = 'FAILURE'
    PARTIAL = 'PARTIAL'

status = QualityControlStatus.SUCCESS
if status != QualityControlStatus.FAILURE:
    print(status)

# %%
import json
data_schema = "/Users/mac/Downloads/IngestProfile_20230214.json"
f = open(data_schema)
datas = json.load(f)
f.close()
res = []
for data in datas:
    row = {}
    for k,v in data.items():
        if k in ["Status", "Source", "EventId"]:
            continue
        elif k == "Address":
            for k1,v1 in v.items():
                if k1 == "Streetname":
                    row[f"AddrStreetName"] = v1
                else:
                    row[f"Addr{k1}"] = v1
        elif k == "UserId":
            row[k] = str(v)
        else:
            row[k] = v 
    row["MaritalStatus"] = "Single"
    res.append(row)
# print(res)
with open('data.json', 'w') as f:
    json.dump(res, f, indent=4, default=str, ensure_ascii=False)

# %%
from tera_etl import quality_control as qc
from tera_etl import normalise_data as nd
import json
schema = {
    'UserId': 'string',
    'HomePhone': ['string', 'null'],
    'WorkPhone': ['string', 'null'],
    'AddrHouseNo': 'string',
    "AddrStreetName": "string",
    'AddrWard': 'string',
    'AddrDistrict': 'string',
    'AddrProvince': 'string',
    'AddrCountry': 'string',
    'Firstname': 'string',
    'Lastname': 'string',
    'Gender': 'string',
    'RegisterDate': 'datetime',
    'DataSource': 'string',
    'MaritalStatus': 'string'
}
f = open("data.json")
datas = json.load(f)
f.close()
a = nd.normalise_process(datas, "UserProfileSchema")
print(a)
# for data in datas:
    # print(data)
    # qc_result = qc.classify_data(data_chunk=data, schema=schema)
    # if qc_result["qc_type"] == qc.QualityControlResult.ACCEPTED:
    #     # print(qc_result["qc_type"])
    #     pass
    # else:
    #     print(qc_result["errors"])
# Out:
# [{'UserId': '202201439260', 'HomePhone': '84369841490', 'WorkPhone': None, 'AddrHouseNo': '', 'AddrStreetName': '', 'AddrWard': '15 NGÕ 341, Phường Xuân Phương', 'AddrDistrict': 'Quận Nam Từ Liêm', 'AddrProvince': 'Thành phố Hà Nội', 'AddrCountry': 'Việt Nam', 'Firstname': 'NGUYỄN THỊ BÍCH ', 'Lastname': 'HIỀN', 'Gender': 'Female', 'RegisterDate': '2022-01-01T00:00:00.00Z', 'DataSource': 'VTVHyundai', 'MaritalStatus': 'Single'}, {'UserId': '202201439262', 'HomePhone': '84984688061', 'WorkPhone': None, 'AddrHouseNo': '', 'AddrStreetName': '', 'AddrWard': 'SN 5 NGÁCH 48 NGÕ 12 PHỐ ĐÀO TẤN, Phường Cống Vị', 'AddrDistrict': 'Quận Ba Đình', 'AddrProvince': 'Thành phố Hà Nội', 'AddrCountry': 'Việt Nam', 'Firstname': 'CHU THỊ MINH ', 'Lastname': 'LOAN', 'Gender': 'Female', 'RegisterDate': '2022-01-01T00:00:00.00Z', 'DataSource': 'VTVHyundai', 'MaritalStatus': 'Single'}, {'UserId': '202201439261', 'HomePhone': '84776434146', 'WorkPhone': None, 'AddrHouseNo': '', 'AddrStreetName': '', 'AddrWard': '50 Đ. LÊ VĂN CHÍ, Phường Linh Trung', 'AddrDistrict': 'Thành phố Thủ Đức', 'AddrProvince': 'Thành Phố Hồ Chí Minh', 'AddrCountry': 'Việt Nam', 'Firstname': 'LÊ THỊ ', 'Lastname': 'DUNG', 'Gender': 'Male', 'RegisterDate': '2022-01-01T00:00:00.00Z', 'DataSource': 'VTVHyundai', 'MaritalStatus': 'Single'}, {'UserId': '202201439263', 'HomePhone': '84347778758', 'WorkPhone': None, 'AddrHouseNo': '', 'AddrStreetName': '', 'AddrWard': '( SAU TRƯỜNG ĐAHỊ HỌC NGUYỄN TẤT THÀNH ), SỐ 413/1B, VƯỜN LÀI, KP 4, Phường An Phú Đông', 'AddrDistrict': 'Quận 12', 'AddrProvince': 'Thành Phố Hồ Chí Minh', 'AddrCountry': 'Việt Nam', 'Firstname': 'NGUYỄN NGỌC ', 'Lastname': 'MAI', 'Gender': 'Female', 'RegisterDate': '2022-01-01T00:00:00.00Z', 'DataSource': 'VTVHyundai', 'MaritalStatus': 'Single'}, {'UserId': '202201439264', 'HomePhone': '84385334415', 'WorkPhone': None, 'AddrHouseNo': '', 'AddrStreetName': '', 'AddrWard': 'TỔ 6 ẤP THANH TUẤN, Xã Thanh Lương', 'AddrDistrict': 'Thị xã Bình Long', 'AddrProvince': 'Tỉnh Bình Phước', 'AddrCountry': 'Việt Nam', 'Firstname': 'VŨ THANH ', 'Lastname': 'SƠN', 'Gender': 'Male', 'RegisterDate': '2022-01-01T00:00:00.00Z', 'DataSource': 'VTVHyundai', 'MaritalStatus': 'Single'}, {'UserId': '202201439265', 'HomePhone': '84974640072', 'WorkPhone': None, 'AddrHouseNo': '', 'AddrStreetName': '', 'AddrWard': 'SỐ 55/1, ĐƯỜNG NGUYỄN HUỆ, ẤP HẬU LÂN, Xã Bà Điểm', 'AddrDistrict': 'Huyện Hóc Môn', 'AddrProvince': 'Thành Phố Hồ Chí Minh', 'AddrCountry': 'Việt Nam', 'Firstname': 'TRẦN THỊ THU ', 'Lastname': 'NGUYỆT', 'Gender': 'Female', 'RegisterDate': '2022-01-01T00:00:00.00Z', 'DataSource': 'VTVHyundai', 'MaritalStatus': 'Single'}, {'UserId': '202201439267', 'HomePhone': '84908725087', 'WorkPhone': None, 'AddrHouseNo': '', 'AddrStreetName': '', 'AddrWard': 'SN 4 Đ. 16 KP 5, Phường Phước Long A', 'AddrDistrict': 'Thành phố Thủ Đức', 'AddrProvince': 'Thành Phố Hồ Chí Minh', 'AddrCountry': 'Việt Nam', 'Firstname': 'LÊ MINH ', 'Lastname': 'HOÀNG', 'Gender': 'Male', 'RegisterDate': '2022-01-01T00:00:00.00Z', 'DataSource': 'VTVHyundai', 'MaritalStatus': 'Single'}, {'UserId': '202201439266', 'HomePhone': '84909532667', 'WorkPhone': None, 'AddrHouseNo': '', 'AddrStreetName': '', 'AddrWard': 'SN 51, KP DƯƠNG PHÚ, Thị Trấn Tân Hoà', 'AddrDistrict': 'Huyện Gò Công Đông', 'AddrProvince': 'Tỉnh Tiền Giang', 'AddrCountry': 'Việt Nam', 'Firstname': 'THÙY ', 'Lastname': 'TRANG', 'Gender': 'Female', 'RegisterDate': '2022-01-01T00:00:00.00Z', 'DataSource': 'VTVHyundai', 'MaritalStatus': 'Single'}, {'UserId': '202201439268', 'HomePhone': '84965138638', 'WorkPhone': None, 'AddrHouseNo': '', 'AddrStreetName': '', 'AddrWard': 'SỐ 38, DƯƠNG VĂN NGA, Phường Rạch Dừa', 'AddrDistrict': 'Thành phố Vũng Tàu', 'AddrProvince': 'Tỉnh Bà Rịa - Vũng Tàu', 'AddrCountry': 'Việt Nam', 'Firstname': 'NGUYỄN THỊ TÂM ', 'Lastname': 'DUY', 'Gender': 'Female', 'RegisterDate': '2022-01-01T00:00:00.00Z', 'DataSource': 'VTVHyundai', 'MaritalStatus': 'Single'}, {'UserId': '202201439269' ...

# %%
from enum import Enum

class QualityControlResult(Enum):
    ACCEPTED = 'ACCEPTED'
    REJECTED = 'REJECTED'


def classify_data(data_chunk, schema, **kwargs) -> QualityControlResult:
    is_accepted = __is_accepted(data_chunk, schema)
    return {
        "qc_type": QualityControlResult.ACCEPTED if is_accepted["status"] else QualityControlResult.REJECTED,
        "errors": []
    }

def __is_accepted(chunk, schema):
    return __has_valid_schema(chunk, schema)


def __has_valid_schema(data, schema):
    return {
        "status": True,
        "errors": [],
    }

# %%
qc_result = classify_data(data_chunk=data, schema=schema)

# %%
qc_result["qc_type"] == QualityControlResult.ACCEPTED

# %%
structures = {
    "Fields": [
      {"Name": "UserId", "FieldType": "string", "Required": True, "Nullable": False, "Comment": "id của user trong hệ thống, phải là kiểu string" },
      {"Name": "HomePhone", "FieldType": "string", "Comment": "Nếu không có thì để trống" },
      {"Name": "WorkPhone", "FieldType": "string", "Comment": "Nếu không có thì để trống" },
      {"Name": "AddrHouseNo", "FieldType": "string", "Comment": "Số nhà" },
      {"Name": "AddrStreetName", "FieldType": "string", "Comment": "Tên đường" },
      {"Name": "AddrWard", "FieldType": "string", "Comment": "Phường / Xã" },
      {"Name": "AddrDistrict", "FieldType": "string", "Comment": "Quận / Huyện / Thành Phố trực thuộc tỉnh" },
      {"Name": "AddrProvince", "FieldType": "string", "Comment": "Tỉnh / Thành phố trực thuộc TW" },
      {"Name": "AddrCountry", "FieldType": "string", "Validation": "Iso Country Code", "Comment": "Tên nước - ISO Country Code - E.g. VN" },
      {"Name": "Firstname", "FieldType": "string", "Comment": "Tên" },
      {"Name": "Lastname", "FieldType": "string", "Comment": "Họ và chữ lót" },
      {"Name": "Gender", "FieldType": "string", "Comment": "Giới tính, tiếng anh, để khỏi bị nhầm lẫn", "Validation": "Male/Female/Other" },
      {"Name": "RegisterDate", "FieldType": "datetime", "Comment": "Ngày đăng ký vào hệ thống" },
      {"Name": "DataSource", "FieldType": "string", "Comment": "DataProviderName" },
      {"Name": "MaritalStatus", "FieldType": "string", "Comment": "Tình trạng hôn nhân", "Validation": "Single/Married" }
    ]
}

# %%
def is_camel_case(s):
    return s != s.lower() and s != s.upper() and "_" not in s


tests = [
    "camel",
    "123213camelCase12312",
    "CamelCase",
    "CAMELCASE",
    "camelcase",
    "Camelcase",
    "Case",
    "camel_case",
    "CAmelCase",
    "VTVHyunhdai",
    "VTVCab",
    "dasdasd_asdasda",
]

for test in tests:
    print(test, is_camel_case(test))
# Out:
# camel False
# 123213camelCase12312 True
# CamelCase True
# CAMELCASE False
# camelcase False
# Camelcase True
# Case True
# camel_case False
# CAmelCase True
# VTVHyunhdai True
# VTVCab True
# dasdasd_asdasda False

# %%
import re
def convert(CamelCase):
    string = re.sub('(.)([A-Z][a-z]+)', r'\1-\2', CamelCase)
    return re.sub('([a-z0-9])([A-Z])', r'\1-\2', string).lower()
for test in tests:
    print(test, convert(test))
# for test in tests:
#     if is_camel_case(test):
#         print(test)
#         print(re.findall(r'[A-Za-z](?:[a-z]+|[A-Z]*(?=[AZ]|$))', test))
# name = 'CamelCaseName'
        # name = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', name)
        # name =  re.sub('([a-z0-9])([A-Z])', r'\1_\2', name).lower()
        # name = re.sub(r'(?<!^)(?=[A-Z])', '-', test).lower()
        # print(name)  # camel_case_name
# Out:
# camel camel
# 123213camelCase12312 123213camel-case12312
# CamelCase camel-case
# CAMELCASE camelcase
# camelcase camelcase
# Camelcase camelcase
# Case case
# camel_case camel_case
# CAmelCase c-amel-case
# VTVHyunhdai vtv-hyunhdai
# VTVCab vtv-cab
# dasdasd_asdasda dasdasd_asdasda
